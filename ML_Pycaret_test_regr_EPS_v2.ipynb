# %%
# Read in data and packages
import pandas as pd
import numpy as np

df = pd.read_csv('ML1_data_adj_v2.csv')

# %%
df1 = df.drop(columns=['Date', 'ticker', 'Year', 'Fwd_ST_Accel_Class_3M', 'Fwd_ST_Accel_3M','Sector','Fwd_Best_EPS_6M_v5Y', 'Fwd_Return_6M', 'Fwd_Return_3M', 'Fwd_Return_1M'])
df1.describe()
# Out:
#        Fwd_Best_EPS_6M       Mkt_Cap   Best_EPS_1M   Best_EPS_3M  \
# count     52663.000000  5.266300e+04  52663.000000  52663.000000
# mean          0.158580  3.856277e+04      0.148181      0.166686
# std           0.300668  1.190055e+05      0.623256      0.375157
# min          -0.988708  3.249532e+02     -2.993548     -1.406977
# 25%           0.000000  4.286605e+03      0.000000     -0.001739
# 50%           0.106354  1.101040e+04      0.000000      0.067773
# 75%           0.290000  2.807057e+04      0.061876      0.279279
# max           1.993151  2.317310e+06      5.985646      3.917949
#
#         Best_EPS_6M   Best_EPS_1Y   Best_EPS_3Y   Best_EPS_5Y  \
# count  52663.000000  52663.000000  52663.000000  52663.000000
# mean       0.161365      0.166059      0.195058      0.233565
# std        0.263672      0.209388      0.172892      0.219233
# min       -0.919422     -0.543590     -0.203883     -0.107213
# 25%        0.008633      0.051301      0.094444      0.109806
# ...

# %%
from pycaret.regression import *

# %%
reg_experiment = setup(df1, target = 'Fwd_Best_EPS_6M', session_id=123, log_experiment=True, experiment_name='Fwd_EPS_6M')
# Out:
# <style type="text/css">
# #T_c1345_row17_col1, #T_c1345_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c1345_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1345_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c1345_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_c1345_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_c1345_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c1345_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c1345_row1_col1" class="data row1 col1" >Fwd_Best_EPS_6M</td>
#     </tr>
#     <tr>
#       <th id="T_c1345_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models(fold=10)
# Out:
# <style type="text/css">
# #T_7cc2a_ th {
#   text-align: left;
# }
# ...

# %%
et1 = create_model('et')
# Out:
# <style type="text/css">
# #T_ff99f_row10_col0, #T_ff99f_row10_col1, #T_ff99f_row10_col2, #T_ff99f_row10_col3, #T_ff99f_row10_col4, #T_ff99f_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_ff99f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff99f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ff99f_row0_col0" class="data row0 col0" >0.0440</td>
#       <td id="T_ff99f_row0_col1" class="data row0 col1" >0.0092</td>
#       <td id="T_ff99f_row0_col2" class="data row0 col2" >0.0957</td>
# ...

# %%
evaluate_model(et1)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
#plot_model(et1)

# %%
#interpret_model(et1)

# %%
#predictions = predict_model(et1)

# %%
# EPS_6M_v5Y
# Read in data and packages
df2 = df.drop(columns=['Date', 'ticker', 'Year', 'Fwd_ST_Accel_Class_3M', 'Fwd_ST_Accel_3M','Sector','Fwd_Best_EPS_6M', 'Fwd_Return_6M', 'Fwd_Return_3M', 'Fwd_Return_1M'])
df2.describe()
# Out:
#        Fwd_Best_EPS_6M_v5Y       Mkt_Cap   Best_EPS_1M   Best_EPS_3M  \
# count         52663.000000  5.266300e+04  52663.000000  52663.000000
# mean              0.642501  3.856277e+04      0.148181      0.166686
# std               1.953389  1.190055e+05      0.623256      0.375157
# min              -9.950293  3.249532e+02     -2.993548     -1.406977
# 25%               0.000000  4.286605e+03      0.000000     -0.001739
# 50%               0.539640  1.101040e+04      0.000000      0.067773
# 75%               1.474491  2.807057e+04      0.061876      0.279279
# max               9.900663  2.317310e+06      5.985646      3.917949
#
#         Best_EPS_6M   Best_EPS_1Y   Best_EPS_3Y   Best_EPS_5Y  \
# count  52663.000000  52663.000000  52663.000000  52663.000000
# mean       0.161365      0.166059      0.195058      0.233565
# std        0.263672      0.209388      0.172892      0.219233
# min       -0.919422     -0.543590     -0.203883     -0.107213
# ...

# %%
from pycaret.regression import *

# %%
reg_experiment = setup(df2, target = 'Fwd_Best_EPS_6M_v5Y', session_id=123, log_experiment=True, experiment_name='Fwd_EPS_6M_v5Y')
# Out:
# <style type="text/css">
# #T_d0964_row17_col1, #T_d0964_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d0964_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0964_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d0964_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_d0964_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_d0964_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d0964_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d0964_row1_col1" class="data row1 col1" >Fwd_Best_EPS_6M_v5Y</td>
#     </tr>
#     <tr>
#       <th id="T_d0964_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models(fold=10)
# Out:
# <style type="text/css">
# #T_5c8bc_ th {
#   text-align: left;
# }
# ...

# %%
et2 = create_model('et')
# Out:
# <style type="text/css">
# #T_de9e7_row10_col0, #T_de9e7_row10_col1, #T_de9e7_row10_col2, #T_de9e7_row10_col3, #T_de9e7_row10_col4, #T_de9e7_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_de9e7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de9e7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_de9e7_row0_col0" class="data row0 col0" >0.2383</td>
#       <td id="T_de9e7_row0_col1" class="data row0 col1" >0.3718</td>
#       <td id="T_de9e7_row0_col2" class="data row0 col2" >0.6098</td>
# ...

# %%
evaluate_model(et2)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
# EPS_Accel_3M
# Read in data and packages
df3 = df.drop(columns=['Date', 'ticker', 'Fwd_ST_Accel_Class_3M', 'Sector','Fwd_Best_EPS_6M', 'Fwd_Best_EPS_6M_v5Y','Fwd_Return_6M', 'Fwd_Return_3M', 'Fwd_Return_1M'])
df3.describe()
# Out:
#        Fwd_ST_Accel_3M       Mkt_Cap   Best_EPS_1M   Best_EPS_3M  \
# count     52663.000000  5.266300e+04  52663.000000  52663.000000
# mean         49.725362  3.856277e+04      0.148181      0.166686
# std          22.730477  1.190055e+05      0.623256      0.375157
# min           0.000000  3.249532e+02     -2.993548     -1.406977
# 25%          32.600000  4.286605e+03      0.000000     -0.001739
# 50%          49.333333  1.101040e+04      0.000000      0.067773
# 75%          66.700000  2.807057e+04      0.061876      0.279279
# max          99.200000  2.317310e+06      5.985646      3.917949
#
#         Best_EPS_6M   Best_EPS_1Y   Best_EPS_3Y   Best_EPS_5Y  \
# count  52663.000000  52663.000000  52663.000000  52663.000000
# mean       0.161365      0.166059      0.195058      0.233565
# std        0.263672      0.209388      0.172892      0.219233
# min       -0.919422     -0.543590     -0.203883     -0.107213
# 25%        0.008633      0.051301      0.094444      0.109806
# ...

# %%
reg_experiment = setup(df3, target = 'Fwd_ST_Accel_3M', session_id=123, log_experiment=True, experiment_name='Fwd_ST_Accel_3M')
# Out:
# <style type="text/css">
# #T_79578_row17_col1, #T_79578_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_79578_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79578_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_79578_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_79578_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_79578_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_79578_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_79578_row1_col1" class="data row1 col1" >Fwd_ST_Accel_3M</td>
#     </tr>
#     <tr>
#       <th id="T_79578_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models(fold=10)
# Out:
# <style type="text/css">
# #T_0824d_ th {
#   text-align: left;
# }
# ...

# %%
et3 = create_model('et')
# Out:
# <style type="text/css">
# #T_83fd5_row10_col0, #T_83fd5_row10_col1, #T_83fd5_row10_col2, #T_83fd5_row10_col3, #T_83fd5_row10_col4, #T_83fd5_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_83fd5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83fd5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_83fd5_row0_col0" class="data row0 col0" >4.6189</td>
#       <td id="T_83fd5_row0_col1" class="data row0 col1" >60.1164</td>
#       <td id="T_83fd5_row0_col2" class="data row0 col2" >7.7535</td>
# ...

# %%
evaluate_model(et3)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…
