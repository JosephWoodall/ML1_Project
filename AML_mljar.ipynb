# %%
import pandas as pd
from supervised import AutoML
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from supervised.automl import AutoML # mljar-supervised

df = pd.read_csv('ML1_data_adj_v3.csv')
# Out:
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
# pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.

# %%
df1 = df.drop(columns=['Date', 'ticker', 'Fwd_Return_3M', 'Fwd_Return_3M_Class', 'Year'])
df1.describe()
# Out:
#        Fwd_Best_EPS_6M       Mkt_Cap   Best_EPS_1M   Best_EPS_3M  \
# count     66543.000000  6.654300e+04  66543.000000  66543.000000
# mean          0.146072  3.963934e+04      0.134926      0.149239
# std           0.346498  1.209661e+05      0.641078      0.408113
# min          -0.998682  2.285343e+02     -2.993548     -1.969543
# 25%          -0.008496  4.091980e+03      0.000000     -0.010204
# 50%           0.101124  1.074958e+04      0.000000      0.060423
# 75%           0.292308  2.820864e+04      0.060302      0.271513
# max           1.993151  2.317310e+06      5.985646      3.970370
#
#         Best_EPS_6M   Best_EPS_1Y   Best_EPS_3Y   Best_EPS_5Y  \
# count  66543.000000  66543.000000  66543.000000  66543.000000
# mean       0.142226      0.146950      0.175486      0.206988
# std        0.288412      0.225683      0.185265      0.227802
# min       -0.998682     -0.901786     -0.315403     -0.192926
# 25%        0.000000      0.034915      0.073810      0.087458
# 50%        0.097981      0.119841      0.145540      0.158129
# 75%        0.263307      0.235416      0.240492      0.266364
# max        1.993151      1.970179      1.985257      1.996078
#
#        Best_EPS_3M_v5Y  Best_EPS_6M_v5Y  ...       ROIC_SD           ROE  \
# count     66543.000000     66543.000000  ...  66543.000000  66543.000000
# mean          0.655999         0.628822  ...      4.363130     21.455667
# std           1.830792         1.224266  ...     12.324927     20.696550
# min          -7.963698        -3.993773  ...      0.102878    -34.297030
# 25%           0.000000         0.000000  ...      1.394105     10.335427
# 50%           0.217910         0.420799  ...      2.406145     14.893621
# 75%           1.271802         1.333494  ...      4.377073     26.106234
# max           7.994405         3.997175  ...    267.476144    191.928086
#
#          ROE_1Y_Chg        ROE_SD       FCF_Mgn  FCF_Mgn_1Y_Chg    FCF_Mgn_SD  \
# count  66543.000000  66543.000000  66543.000000    66543.000000  66543.000000
# mean       0.485937     13.604074     14.862171        0.645832      5.215309
# std       37.653509     46.717679     16.419273       21.480849     14.647090
# min    -1911.423912      0.131123   -186.202847     -786.589581      0.171153
# 25%       -2.172367      1.977712      5.892424       -1.997974      1.693878
# 50%        0.407125      3.818095     12.112964        0.596600      2.874146
# 75%        4.261422      8.287664     23.020334        3.405229      4.743748
# max      184.928481    804.311314    192.327044      473.918884    315.433750
#
#              Op_Mgn  Op_Mgn_1Y_Chg     Op_Mgn_SD
# count  66543.000000   66543.000000  66543.000000
# mean      19.793758       0.321828      2.435875
# std       13.151157       4.160568      3.073220
# min       -3.827139     -83.005348      0.040187
# 25%        9.792099      -0.869289      0.853625
# 50%       17.111181       0.163065      1.617410
# 75%       26.899368       1.543946      3.045869
# max       96.975075      67.269338     54.359769
#
# [8 rows x 69 columns]

# %%
X = df1.drop(columns=['Fwd_Best_EPS_6M'])
X.describe()
# Out:
#             Mkt_Cap   Best_EPS_1M   Best_EPS_3M   Best_EPS_6M   Best_EPS_1Y  \
# count  6.654300e+04  66543.000000  66543.000000  66543.000000  66543.000000
# mean   3.963934e+04      0.134926      0.149239      0.142226      0.146950
# std    1.209661e+05      0.641078      0.408113      0.288412      0.225683
# min    2.285343e+02     -2.993548     -1.969543     -0.998682     -0.901786
# 25%    4.091980e+03      0.000000     -0.010204      0.000000      0.034915
# 50%    1.074958e+04      0.000000      0.060423      0.097981      0.119841
# 75%    2.820864e+04      0.060302      0.271513      0.263307      0.235416
# max    2.317310e+06      5.985646      3.970370      1.993151      1.970179
#
#         Best_EPS_3Y   Best_EPS_5Y  Best_EPS_3M_v5Y  Best_EPS_6M_v5Y  \
# count  66543.000000  66543.000000     66543.000000     66543.000000
# mean       0.175486      0.206988         0.655999         0.628822
# std        0.185265      0.227802         1.830792         1.224266
# min       -0.315403     -0.192926        -7.963698        -3.993773
# 25%        0.073810      0.087458         0.000000         0.000000
# 50%        0.145540      0.158129         0.217910         0.420799
# 75%        0.240492      0.266364         1.271802         1.333494
# max        1.985257      1.996078         7.994405         3.997175
#
#        Best_EPS_1Y_v5Y  ...       ROIC_SD           ROE    ROE_1Y_Chg  \
# count     66543.000000  ...  66543.000000  66543.000000  66543.000000
# mean          0.665375  ...      4.363130     21.455667      0.485937
# std           0.940079  ...     12.324927     20.696550     37.653509
# min          -3.942308  ...      0.102878    -34.297030  -1911.423912
# 25%           0.043108  ...      1.394105     10.335427     -2.172367
# 50%           0.596839  ...      2.406145     14.893621      0.407125
# 75%           1.122095  ...      4.377073     26.106234      4.261422
# max           3.994903  ...    267.476144    191.928086    184.928481
#
#              ROE_SD       FCF_Mgn  FCF_Mgn_1Y_Chg    FCF_Mgn_SD        Op_Mgn  \
# count  66543.000000  66543.000000    66543.000000  66543.000000  66543.000000
# mean      13.604074     14.862171        0.645832      5.215309     19.793758
# std       46.717679     16.419273       21.480849     14.647090     13.151157
# min        0.131123   -186.202847     -786.589581      0.171153     -3.827139
# 25%        1.977712      5.892424       -1.997974      1.693878      9.792099
# 50%        3.818095     12.112964        0.596600      2.874146     17.111181
# 75%        8.287664     23.020334        3.405229      4.743748     26.899368
# max      804.311314    192.327044      473.918884    315.433750     96.975075
#
#        Op_Mgn_1Y_Chg     Op_Mgn_SD
# count   66543.000000  66543.000000
# mean        0.321828      2.435875
# std         4.160568      3.073220
# min       -83.005348      0.040187
# 25%        -0.869289      0.853625
# 50%         0.163065      1.617410
# 75%         1.543946      3.045869
# max        67.269338     54.359769
#
# [8 rows x 68 columns]

# %%
y = df1[['Fwd_Best_EPS_6M']]
y.describe()
# Out:
#        Fwd_Best_EPS_6M
# count     66543.000000
# mean          0.146072
# std           0.346498
# min          -0.998682
# 25%          -0.008496
# 50%           0.101124
# 75%           0.292308
# max           1.993151

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.2,random_state =123)

# %%
automl = AutoML(mode="Perform")

# %%
automl.fit(X_train,y_train)
# Out:
# Linear algorithm was disabled.
# AutoML directory: AutoML_2
# The task is regression with evaluation metric rmse
# AutoML will use algorithms: ['Random Forest', 'LightGBM', 'Xgboost', 'CatBoost', 'Neural Network']
# AutoML will ensemble available models
# AutoML steps: ['simple_algorithms', 'default_algorithms', 'not_so_random', 'golden_features', 'insert_random_feature', 'features_selection', 'hill_climbing_1', 'hill_climbing_2', 'ensemble']
# Skip simple_algorithms because no parameters were generated.
# * Step default_algorithms will try to check up to 5 models
# 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
# 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# 'evals_result' argument is deprecated and will be removed in a future release of LightGBM. Pass 'record_evaluation()' callback via 'callbacks' argument instead.
# 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
# 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# 'evals_result' argument is deprecated and will be removed in a future release of LightGBM. Pass 'record_evaluation()' callback via 'callbacks' argument instead.
# 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
# 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# 'evals_result' argument is deprecated and will be removed in a future release of LightGBM. Pass 'record_evaluation()' callback via 'callbacks' argument instead.
# 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
# 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# 'evals_result' argument is deprecated and will be removed in a future release of LightGBM. Pass 'record_evaluation()' callback via 'callbacks' argument instead.
# 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
# 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
# 'evals_result' argument is deprecated and will be removed in a future release of LightGBM. Pass 'record_evaluation()' callback via 'callbacks' argument instead.
# 1_Default_LightGBM rmse 0.086362 trained in 2321.77 seconds (1-sample predict time 0.0928 seconds)
# * Step not_so_random will try to check up to 20 models
# 2_Xgboost rmse 0.091644 trained in 1521.02 seconds (1-sample predict time 0.0781 seconds)
# Skip golden_features because no parameters were generated.
# Skip insert_random_feature because no parameters were generated.
# Skip features_selection because no parameters were generated.
# Skip hill_climbing_1 because of the time limit.
# Skip hill_climbing_2 because of the time limit.
# * Step ensemble will try to check up to 1 model
# Ensemble rmse 0.086351 trained in 0.19 seconds (1-sample predict time 0.1759 seconds)
# AutoML fit time: 3854.3 seconds
# AutoML best model: Ensemble
# AutoML(mode='Perform')

# %%
# compute the MSE on test data
predictions = automl.predict(X_test)
print("Test MSE:", mean_squared_error(y_test, predictions))
# Out:
# Test MSE: 0.007252745519558428

# %%
a = AutoML(algorithms=['LightGBM'],total_time_limit=30,
           explain_level=2,golden_features=True,
           validation_strategy={
            "validation_type": "kfold",
            "k_folds": 10,
            "shuffle": False,
            "stratify": True,
            })

# %%
a.fit(X_train,y_train)
# Out:
# AutoML directory: AutoML_4
# The task is regression with evaluation metric rmse
# AutoML will use algorithms: ['LightGBM']
# AutoML will ensemble available models
# 2022-02-12 17:58:27,131 supervised.exceptions ERROR No models produced.
# Please check your data or submit a Github issue at https://github.com/mljar/mljar-supervised/issues/new.
# AutoML steps: ['simple_algorithms', 'default_algorithms', 'golden_features', 'ensemble']
# Skip simple_algorithms because no parameters were generated.
# Skip default_algorithms because of the time limit.
# Skip golden_features because no parameters were generated.
# ---------------------------------------------------------------------------
# AutoMLException                           Traceback (most recent call last)
# Input In [12], in <module>
# ----> 1 a.fit(X_train,y_train)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\supervised\automl.py:337, in AutoML.fit(self, X, y, sample_weight, cv)
#     321 def fit(self, X, y, sample_weight=None, cv=None):
#     322     """Fit the AutoML model.
#     323
#     324     Arguments:
#    (...)
#     335         AutoML object: Returns `self`
#     336     """
# --> 337     return self._fit(X, y, sample_weight, cv)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\supervised\base_automl.py:1123, in BaseAutoML._fit(self, X, y, sample_weight, cv)
#    1120     self.verbose_print(f"AutoML best model: {self._best_model.get_name()}")
#    1122 except Exception as e:
# -> 1123     raise e
#    1125 return self
#
# File ~\AppData\Roaming\Python\Python39\site-packages\supervised\base_automl.py:1040, in BaseAutoML._fit(self, X, y, sample_weight, cv)
#    1038 if "hill_climbing" in step or step in ["ensemble", "stack"]:
#    1039     if len(self._models) == 0:
# -> 1040         raise AutoMLException(
#    1041             "No models produced. \nPlease check your data or"
#    1042             " submit a Github issue at https://github.com/mljar/mljar-supervised/issues/new."
#    1043         )
#    1045 generated_params = []
#    1046 if step in self._all_params:
#
# AutoMLException: No models produced.
# Please check your data or submit a Github issue at https://github.com/mljar/mljar-supervised/issues/new.

# %%
# compute the MSE on test data
predictions = a.predict(X_test)
print("Test MSE:", mean_squared_error(y_test, predictions))
